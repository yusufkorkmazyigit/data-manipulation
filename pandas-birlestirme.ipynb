# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # BİRLESTİRME (JOİN) İSLEMLERİ

# %%
m = np.random.randint(1,30,size=(5,3))
df1 = pd.DataFrame(m, columns=["var1","var2","var3"])
df1
# Out:
#    var1  var2  var3
# 0    13    18    22
# 1    12    26     1
# 2     7    28    20
# 3    15    20    15
# 4    17     6    14

# %%
df2 = df1 + 89
df2
# Out:
#    var1  var2  var3
# 0   102   107   111
# 1   101   115    90
# 2    96   117   109
# 3   104   109   104
# 4   106    95   103

# %%
pd.concat([df1,df2],ignore_index=True)
# Out:
#    var1  var2  var3
# 0    13    18    22
# 1    12    26     1
# 2     7    28    20
# 3    15    20    15
# 4    17     6    14
# 5   102   107   111
# 6   101   115    90
# 7    96   117   109
# 8   104   109   104
# 9   106    95   103

# %%
df1.columns
# Out:
# Index(['var1', 'var2', 'var3'], dtype='object')

# %%
df2.columns = ["var1","var2","deg3"]

# %%
df2
# Out:
#    var1  var2  deg3
# 0   102   107   111
# 1   101   115    90
# 2    96   117   109
# 3   104   109   104
# 4   106    95   103

# %%
df1
# Out:
#    var1  var2  var3
# 0    13    18    22
# 1    12    26     1
# 2     7    28    20
# 3    15    20    15
# 4    17     6    14

# %%
pd.concat([df1,df2],join="inner",ignore_index=True) #kesişen elemanları birlestirdi
# Out:
#    var1  var2
# 0    13    18
# 1    12    26
# 2     7    28
# 3    15    20
# 4    17     6
# 5   102   107
# 6   101   115
# 7    96   117
# 8   104   109
# 9   106    95

# %%
# Ileri birlestirme islemleri

# %%
df1 = pd.DataFrame({"calisanlar":["Ali","Veli","Ayse","Fatma"],
                    "grup":["Muhasebe","Muhendislik","Muhendislik","IK"]})
df1
# Out:
#   calisanlar         grup
# 0        Ali     Muhasebe
# 1       Veli  Muhendislik
# 2       Ayse  Muhendislik
# 3      Fatma           IK

# %%
df2 = pd.DataFrame({"calisanlar":["Ali","Veli","Ayse","Fatma"],
                    "ilk_giris":[2010,2009,2014,2019]})
df2
# Out:
#   calisanlar  ilk_giris
# 0        Ali       2010
# 1       Veli       2009
# 2       Ayse       2014
# 3      Fatma       2019

# %%
#birebir birlestirme

# %%
pd.merge(df1,df2)
# Out:
#   calisanlar         grup  ilk_giris
# 0        Ali     Muhasebe       2010
# 1       Veli  Muhendislik       2009
# 2       Ayse  Muhendislik       2014
# 3      Fatma           IK       2019

# %%
pd.merge(df1,df2,on="calisanlar")
# Out:
#   calisanlar         grup  ilk_giris
# 0        Ali     Muhasebe       2010
# 1       Veli  Muhendislik       2009
# 2       Ayse  Muhendislik       2014
# 3      Fatma           IK       2019

# %%
#coktan teke

# %%
df3 = pd.merge(df1,df2)
df3
# Out:
#   calisanlar         grup  ilk_giris
# 0        Ali     Muhasebe       2010
# 1       Veli  Muhendislik       2009
# 2       Ayse  Muhendislik       2014
# 3      Fatma           IK       2019

# %%
df4 = pd.DataFrame({"grup":["Muhasebe","Muhendislik","IK"],
                    "mudur":["Caner","Mustafa","Arzu"]})

df4
# Out:
#           grup    mudur
# 0     Muhasebe    Caner
# 1  Muhendislik  Mustafa
# 2           IK     Arzu

# %%
pd.merge(df3,df4)
# Out:
#   calisanlar         grup  ilk_giris    mudur
# 0        Ali     Muhasebe       2010    Caner
# 1       Veli  Muhendislik       2009  Mustafa
# 2       Ayse  Muhendislik       2014  Mustafa
# 3      Fatma           IK       2019     Arzu

# %%
#çoktan çoka

# %%
df5 = pd.DataFrame({'grup': ['Muhasebe', 'Muhasebe',
                              'Muhendislik', 'Muhendislik', 'İK', 'İK'],
                    'yetenekler': ['matematik', 'excel', 'kodlama', 'linux',
                               'excel', 'yonetim']})

df5
# Out:
#           grup yetenekler
# 0     Muhasebe  matematik
# 1     Muhasebe      excel
# 2  Muhendislik    kodlama
# 3  Muhendislik      linux
# 4           İK      excel
# 5           İK    yonetim

# %%
pd.merge(df1,df5)
# Out:
#   calisanlar         grup yetenekler
# 0        Ali     Muhasebe  matematik
# 1        Ali     Muhasebe      excel
# 2       Veli  Muhendislik    kodlama
# 3       Veli  Muhendislik      linux
# 4       Ayse  Muhendislik    kodlama
# 5       Ayse  Muhendislik      linux
